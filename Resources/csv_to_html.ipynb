# %%
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
test = pd.read_csv('cities.csv', index_col=False)
test.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0        Ixtapa           5      MX  1559155506        65  20.71
# 1        1  Kruisfontein           9      ZA  1559156077        80 -34.00
# 2        2   Belaya Gora          47      RU  1559155545        52  68.54
# 3        3         Vaini          92      IN  1559155801        81  15.34
# 4        4      Misratah          65      LY  1559155795        71  32.38
#
#       Lng  Max Temp  Wind Speed
# 0 -105.21     84.00        8.05
# 1   24.73     56.14        6.67
# 2  146.19     48.58       18.34
# 3   74.49     82.24        3.15
# 4   15.09     71.08       13.02

# %%
filepath = r"cities.csv"
cities_df = pd.read_csv(filepath)
cities_df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0        Ixtapa           5      MX  1559155506        65  20.71
# 1        1  Kruisfontein           9      ZA  1559156077        80 -34.00
# 2        2   Belaya Gora          47      RU  1559155545        52  68.54
# 3        3         Vaini          92      IN  1559155801        81  15.34
# 4        4      Misratah          65      LY  1559155795        71  32.38
#
#       Lng  Max Temp  Wind Speed
# 0 -105.21     84.00        8.05
# 1   24.73     56.14        6.67
# 2  146.19     48.58       18.34
# 3   74.49     82.24        3.15
# 4   15.09     71.08       13.02

# %%
cities_df2 = pd.read_csv('cities.csv', index_col=0)
cities_df2.head()
# Out:
#                  City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0              Ixtapa           5      MX  1559155506        65  20.71
# 1        Kruisfontein           9      ZA  1559156077        80 -34.00
# 2         Belaya Gora          47      RU  1559155545        52  68.54
# 3               Vaini          92      IN  1559155801        81  15.34
# 4            Misratah          65      LY  1559155795        71  32.38
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 0       -105.21     84.00        8.05
# 1         24.73     56.14        6.67
# 2        146.19     48.58       18.34
# 3         74.49     82.24        3.15
# 4         15.09     71.08       13.02

# %%
write_csv1 = cities_df.to_html(open('cities.html', 'w'))
write_csv1

# %%
write_csv2 = cities_df2.to_html(open('cities(2).html', 'w'))
write_csv2

# %%
html_string = cities_df.to_html(header=True, index=False)
html_string
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>City_ID</th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>0</td>\n      <td>Ixtapa</td>\n      <td>5</td>\n      <td>MX</td>\n      <td>1559155506</td>\n      <td>65</td>\n      <td>20.71</td>\n      <td>-105.21</td>\n      <td>84.00</td>\n      <td>8.05</td>\n    </tr>\n    <tr>\n      <td>1</td>\n      <td>Kruisfontein</td>\n      <td>9</td>\n      <td>ZA</td>\n      <td>1559156077</td>\n      <td>80</td>\n      <td>-34.00</td>\n      <td>24.73</td>\n      <td>56.14</td>\n      <td>6.67</td>\n    </tr>\n    <tr>\n      <td>2</td>\n      <td>Belaya Gora</td>\n      <td>47</td>\n      <td>RU</td>\n      <td>1559155545</td>\n      <td>52</td>\n      <td>68.54</td>\n      <t
# ...

# %%
soup = bs(html_string, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <table border="1" class="dataframe">
#  <thead>
#   <tr style="text-align: right;">
#    <th>
#     City_ID
#    </th>
#    <th>
#     City
#    </th>
#    <th>
#     Cloudiness
#    </th>
#    <th>
#     Country
#    </th>
#    <th>
#     Date
#    </th>
#    <th>
#     Humidity
#    </th>
#    <th>
#     Lat
#    </th>
#    <th>
#     Lng
#    </th>
#    <th>
#     Max Temp
#    </th>
#    <th>
#     Wind Speed
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <td>
#     0
#    </td>
#    <td>
#     Ixtapa
#    </td>
#    <td>
#     5
#    </td>
#    <td>
#     MX
#    </td>
#    <td>
#     1559155506
#    </td>
#    <td>
#     65
#    </td>
#    <td>
#     20.71
#    </td>
#    <td>
#     -105.21
#    </td>
#    <td>
#     84.00
#    </td>
#    <td>
#     8.05
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td>
#     Kruisfontein
#    </td>
#    <td>
#     9
#    </td>
#    <td>
#     ZA
#    </td>
#    <td>
#     1559156077
#    </td>
#    <td>
#     80
# ...
